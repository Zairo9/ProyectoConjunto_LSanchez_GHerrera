# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Gustavo Adrián Herrera Barragán & Luis Eduardo Sánchez Soto.
#
# **Fecha:** 14 de marzo del 2022.
#
# **Expediente** : 734546 & 734350 .
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Zairo9/ProyectoConjunto_LSanchez_GHerrera

# %% [markdown]
# # Tarea 5: Clase: 10

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import optimize

# %% [markdown]
# ### Ejercicio 1:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
fx = lambda x: 30*(x**2-2*x**3+x**4)
tx = lambda x: 2*np.sin(np.pi*x)
dominio = np.linspace(0,1,200)
plt.plot(dominio, fx(dominio), label='fx')
plt.plot(dominio, tx(dominio), label='tx')
plt.legend();

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 2:
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# #### Código de solución estudiante 1:

# %% [markdown]
# \begin{gathered}
# g(x)=\frac{t(x)}{C} \\
# C=\int_0^1 t(x) d x \\
# C=\int a \sin (\pi x) d x=\frac{-a}{\pi} \cos (\pi x) \\
# \left.\int_0^1 a \sin (\pi x) d x-\left[\frac{-a}{\pi} \cos (\pi)\right]-\mid \frac{-a}{\pi} \cos (0)\right] \\
# \left\{\frac{-a}{\pi} \cos (-1) \mid-\left[\frac{-a}{\pi} \cos (1)\right]\right. \\
# C=\frac{2 a}{\pi} \\
# g(x)-\frac{a \sin (\pi x)}{\frac{2 \pi}{\pi}} \\
# g(x)=\frac{\sin (\pi x)}{\frac{2}{\pi}}
# \end{gathered}

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
#Código:

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 3:
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
#Código:

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 4:
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
t = lambda x: (np.arccos(-2*np.random.rand(x)+1))/np.pi

# %%
plt.figure(figsize = (10,8))
plt.hist(comprobacion,bins = 40, color = '#FA5D22', density = True, label = 'datos generados')
x = np.linspace(0.01,0.99,200)
y = lambda x: (np.pi/2)*np.sin(np.pi*x)
plt.plot(x,y(x),'k',lw = 3,  label = 'Función de distribución')
plt.title('Histograma de los datos generados por método de la transformada inversa')
plt.ylabel('Probabilidad')
plt.xlabel('Muestras')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-49d82b3a34ab> in <module>
#       1 plt.figure(figsize = (10,8))
# ----> 2 plt.hist(comprobacion,bins = 40, color = '#FA5D22', density = True, label = 'datos generados')
#       3 x = np.linspace(0.01,0.99,200)
#       4 y = lambda x: (np.pi/2)*np.sin(np.pi*x)
#       5 plt.plot(x,y(x),'k',lw = 3,  label = 'Función de distribución')
#
# NameError: name 'comprobacion' is not defined

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 5:
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
#Código:

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 6:
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
#Código:

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 7:
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %% [markdown]
# #### Código de solución estudiante 1:

# %%
#Código:

# %% [markdown]
# #### Código de solución estudiante 2:

# %%
#Código:

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Creado con Jupyter por: Gustavo Adrián Herrera Barragán & Luis Eduardo Sánchez Soto.
# </footer>
